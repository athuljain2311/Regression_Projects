# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for year in range(2008,2024):
    df = pd.read_csv(f'runs_wickets_per_season\\{year}_batters.csv')
    print(f'{year} : {len(df.columns)}, {len(set(df.columns))}')
# Out:
# 2008 : 43, 43
# 2009 : 43, 43
# 2010 : 43, 43
# 2011 : 43, 43
# 2012 : 43, 43
# 2013 : 43, 43
# 2014 : 43, 43
# 2015 : 43, 43
# 2016 : 43, 43
# 2017 : 43, 43
# 2018 : 43, 43
# 2019 : 43, 43
# 2020 : 43, 43
# 2021 : 43, 43
# 2022 : 42, 42
# 2023 : 42, 42

# %%
df_21 = pd.read_csv('runs_wickets_per_season\\2021_batters.csv')
df_23 = pd.read_csv('runs_wickets_per_season\\2023_batters.csv')

# %%
df_21.head()
# Out:
#        StrikerName  PlayerId  Matches  PlayerDOB  RightHandedBat  Nationality  \
# 0  Ruturaj Gaikwad       102       16        NaN             NaN          NaN
# 1   Faf du Plessis        94       16        NaN             NaN          NaN
# 2         KL Rahul        19       13        NaN             NaN          NaN
# 3   Shikhar Dhawan        11       16        NaN             NaN          NaN
# 4    Glenn Maxwell        28       15        NaN             NaN          NaN
#
#    TCompetitionID  TStrikerID  TTeamID TeamCode  ... Outs  NotOuts  \
# 0           10013         NaN      NaN      CSK  ...   14        2
# 1           10013         NaN      NaN      CSK  ...   14        2
# 2           10013         NaN      NaN     PBKS  ...   10        3
# 3           10013         NaN      NaN       DC  ...   15        1
# 4           10013         NaN      NaN      RCB  ...   12        2
#
#    BattingAveragesss  FiftyPlusRuns  Centuries  DoubleCenturies  HighestScore  \
# ...

# %%
df_23.head()
# Out:
#         StrikerName  PlayerId  Matches   PlayerDOB  RightHandedBat  \
# 0      Shubman Gill        62       17  0000-00-00            True
# 1    Faf Du Plessis        94       14  0000-00-00            True
# 2      Devon Conway       601       16  0000-00-00           False
# 3       Virat Kohli         2       14  0000-00-00            True
# 4  Yashasvi Jaiswal       533       14  0000-00-00           False
#
#   Nationality  TCompetitionID                            TStrikerID  TTeamID  \
# 0      Indian             107  2019-100mb00000000062-8fa4884a17f311       35
# 1    Overseas             107  2019-100mb00000000094-1e8fa14543ee11       19
# 2    Overseas             107  2021-100mb00000000601-517399b0ceaf11       13
# 3      Indian             107   2018-wicb00000000002-47ea5a6ae99a11       19
# 4      Indian             107  2020-100mb00000000533-e895f279639811       18
#
#   TeamCode  ... NotOuts  BattingAveragesss  FiftyPlusRuns Centuries  \
# ...

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StrikerName        149 non-null    object
#  1   PlayerId           149 non-null    int64
#  2   Matches            149 non-null    int64
#  3   PlayerDOB          0 non-null      float64
#  4   RightHandedBat     0 non-null      float64
#  5   Nationality        0 non-null      float64
#  6   TCompetitionID     149 non-null    int64
#  7   TStrikerID         0 non-null      float64
#  8   TTeamID            0 non-null      float64
#  9   TeamCode           149 non-null    object
#  10  TeamName           149 non-null    object
#  11  CompetitionID      149 non-null    int64
#  12  TeamID             0 non-null      float64
#  13  StrikerID          0 non-null      float64
#  14  Innings            149 non-null    int64
#  15  Extras             0 non-null      float64
# ...

# %%
df_23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StrikerName        166 non-null    object
#  1   PlayerId           166 non-null    int64
#  2   Matches            166 non-null    int64
#  3   PlayerDOB          166 non-null    object
#  4   RightHandedBat     166 non-null    bool
#  5   Nationality        166 non-null    object
#  6   TCompetitionID     166 non-null    int64
#  7   TStrikerID         166 non-null    object
#  8   TTeamID            166 non-null    int64
#  9   TeamCode           166 non-null    object
#  10  TeamName           166 non-null    object
#  11  CompetitionID      166 non-null    int64
#  12  TeamID             166 non-null    int64
#  13  StrikerID          166 non-null    object
#  14  Innings            166 non-null    int64
#  15  Extras             166 non-null    int64
# ...

# %%
df_21.shape
# Out:
# (149, 43)

# %%
df_23.shape
# Out:
# (166, 42)

# %%
col_21 = set(df_21.columns)
col_23 = set(df_23.columns)
len(col_21.intersection(col_23))
# Out:
# 41

# %%
col_21.difference(col_23)
# Out:
# {'Most_4s', 'Most_6s'}

# %%
col_23.difference(col_21)
# Out:
# {'ClientPlayerID'}

# %%
df_08 = pd.read_csv('runs_wickets_per_season\\2008_batters.csv')

# %%
set(df_08.columns).difference(col_21)
# Out:
# set()

# %%
set(df_08.columns).difference(col_23)
# Out:
# {'Most_4s', 'Most_6s'}

# %%
df_21[['StrikerName','Fours','Sixes','Most_4s','Most_6s']]
# Out:
#          StrikerName  Fours  Sixes  Most_4s  Most_6s
# 0    Ruturaj Gaikwad     64     23       64       23
# 1     Faf du Plessis     60     23       60       23
# 2           KL Rahul     48     30       48       30
# 3     Shikhar Dhawan     63     16       63       16
# 4      Glenn Maxwell     48     21       48       21
# ..               ...    ...    ...      ...      ...
# 144       Anuj Rawat      0      0        0        0
# 145     Marco Jansen      0      0        0        0
# 146    Sarfaraz Khan      0      0        0        0
# 147    Jimmy Neesham      0      0        0        0
# 148  Prasidh Krishna      0      0        0        0
#
# [149 rows x 5 columns]

# %%
dfs = {}
for year in range(2008,2024):
    df = pd.read_csv(f'runs_wickets_per_season\\{year}_batters.csv')
    if year in [2022,2023]:
        df.drop(columns=['ClientPlayerID'],inplace=True)
    else:
        df.drop(columns=['Most_4s','Most_6s'],inplace=True)
    dfs[year] = df
    print(f'{year} : {len(df.columns)}, {len(set(df.columns))}')
# Out:
# 2008 : 41, 41
# 2009 : 41, 41
# 2010 : 41, 41
# 2011 : 41, 41
# 2012 : 41, 41
# 2013 : 41, 41
# 2014 : 41, 41
# 2015 : 41, 41
# 2016 : 41, 41
# 2017 : 41, 41
# 2018 : 41, 41
# 2019 : 41, 41
# 2020 : 41, 41
# 2021 : 41, 41
# 2022 : 41, 41
# 2023 : 41, 41

# %%
cols, year, flag = None, 2008, 0

for df in dfs.values():
    if cols is None:
        cols = sorted(df.columns)
    else:
        if cols != sorted(df.columns):
            print(year)
            flag = flag + 1
    year = year + 1

if flag == 0:
    print('All Dataframes have the same Columns')
# Out:
# All Dataframes have the same Columns

# %%
dfs[2023].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StrikerName        166 non-null    object
#  1   PlayerId           166 non-null    int64
#  2   Matches            166 non-null    int64
#  3   PlayerDOB          166 non-null    object
#  4   RightHandedBat     166 non-null    bool
#  5   Nationality        166 non-null    object
#  6   TCompetitionID     166 non-null    int64
#  7   TStrikerID         166 non-null    object
#  8   TTeamID            166 non-null    int64
#  9   TeamCode           166 non-null    object
#  10  TeamName           166 non-null    object
#  11  CompetitionID      166 non-null    int64
#  12  TeamID             166 non-null    int64
#  13  StrikerID          166 non-null    object
#  14  Innings            166 non-null    int64
#  15  Extras             166 non-null    int64
# ...

# %%
temp_df = dfs[2023][['StrikerName','TotalRuns','Innings','Outs','BattingAveragesss','BattingAverage']]
temp_df
# Out:
#              StrikerName  TotalRuns  Innings  Outs  BattingAveragesss  \
# 0           Shubman Gill        890       17    15              445.0
# 1         Faf Du Plessis        730       14    13              730.0
# 2           Devon Conway        672       15    13              336.0
# 3            Virat Kohli        639       14    12              319.5
# 4       Yashasvi Jaiswal        625       14    13              625.0
# ..                   ...        ...      ...   ...                ...
# 161       Mohammed Siraj          1        2     1                1.0
# 162        Yudhvir Singh          1        2     2                NaN
# 163     Fazalhaq Farooqi          1        1     0                1.0
# 164         Nathan Ellis          1        2     2                NaN
# 165  Varun Chakaravarthy          1        2     1                1.0
#
#     BattingAverage
# 0            59.33
# 1            56.15
# 2            51.69
# 3            53.25
# 4            48.08
# ...

# %%
temp_df[temp_df['Outs'] == 0]
# Out:
#            StrikerName  TotalRuns  Innings  Outs  BattingAveragesss  \
# 97        David Willey         35        3     0              11.66
# 109    Mayank Markande         21        3     0               7.00
# 118       Akeal Hosein         16        1     0              16.00
# 127       Kedar Jadhav         12        1     0              12.00
# 137       Mukesh Kumar          7        3     0               2.33
# 139     Alzarri Joseph          7        2     0               3.50
# 142  Jason Behrendorff          6        2     0               3.00
# 146       Jofra Archer          4        2     0               2.00
# 148      Vaibhav Arora          3        2     0               1.50
# 150     Arshdeep Singh          2        2     0               1.00
# 151   Mitchell Santner          2        2     0               1.00
# 152      Swapnil Singh          2        1     0               2.00
# 154     Sandeep Sharma          2        2     0               1.00
# ...

# %%
dfs[2023][dfs[2023]['Stumpings'] == 3]
# Out:
#         StrikerName  PlayerId  Matches   PlayerDOB  RightHandedBat  \
# 9      Ishan Kishan       164       15  0000-00-00           False
# 21     Sanju Samson       190       14  0000-00-00            True
# 23  Nicholas Pooran       136       15  0000-00-00           False
# 72         MS Dhoni        57       16  0000-00-00            True
#
#    Nationality  TCompetitionID                            TStrikerID  TTeamID  \
# 9       Indian             107  2019-100mb00000000164-8ae075db44ad11       17
# 21      Indian             107  2019-100mb00000000190-c62cbae544b711       18
# 23    Overseas             107  2019-100mb00000000136-9313d156449c11       77
# 72      Indian             107  2019-100mb00000000057-57100cf415ba11       13
#
#    TeamCode  ... Outs  NotOuts  BattingAveragesss FiftyPlusRuns  Centuries  \
# 9        MI  ...   15        0                NaN             3          0
# 21       RR  ...   12        2             181.00             3          0
# ...

# %%
dfs[2023][dfs[2023]['PlayerId'] == 190]['StrikerName'].values[0]
# Out:
# 'Sanju Samson'

# %%
dfs[2008].sort_values('StrikerName',ascending=True).tail(25)
# Out:
#                  StrikerName  PlayerId  Matches  PlayerDOB  RightHandedBat  \
# 121              Sunil Joshi         0        4        NaN             NaN
# 125              Sunny Sohal         0        2        NaN             NaN
# 7               Suresh Raina       106       16        NaN             NaN
# 17          Swapnil Asnodkar         0        9        NaN             NaN
# 119        Tanmay Srivastava         0        5        NaN             NaN
# 116            Taruwar Kohli         0        2        NaN             NaN
# 89             Tatenda Taibu         0        3        NaN             NaN
# 57      Tillakaratne Dilshan       484        7        NaN             NaN
# 79                  Umar Gul         0        6        NaN             NaN
# 41                VVS Laxman         0        6        NaN             NaN
# 20             Venugopal Rao         0       11        NaN             NaN
# ...

# %%
for df in dfs.values():
    try:
        temp_df = df[df['PlayerId'] == 17]
        name = temp_df['StrikerName'].values[0]
        print(name)
    except:
        print('Player does not exist')
# Out:
# Player does not exist
# Player does not exist
# Player does not exist
# Player does not exist
# Player does not exist
# Player does not exist
# Player does not exist
# Player does not exist
# Player does not exist
# Krunal Pandya
# Krunal Pandya
# Krunal Pandya
# Krunal Pandya
# Krunal Pandya
# Krunal Pandya
# Krunal Pandya

# %%
# !pip install beautifulsoup4
# !pip install google

# %%
from bs4 import BeautifulSoup
from googlesearch import search

# %%
import requests
import json

# %%
def googler(query):
    for url in search(query,num=10):
        if 'https://www.espncricinfo.com/cricketers' in url:
            return url

# %%
query = 'Shaun Marsh'

# %%
for url in search(query,num=10):
    if 'www.espncricinfo.com' in url:
        print(url)
# Out:
# https://www.espncricinfo.com/cricketers/shaun-marsh-6683
# https://www.espncricinfo.com/cricketers/shaun-marsh-6683/matches
# https://www.espncricinfo.com/cricketers/shaun-marsh-6683/bowling-batting-stats
# https://www.espncricinfo.com/cricketers/shaun-marsh-6683/photos
# https://www.espncricinfo.com/cricketers/shaun-marsh-6683/tests-odi-t20-records

# %%
espn_url = googler('Shaun Marsh')
espn_url
# Out:
# 'https://www.espncricinfo.com/cricketers/shaun-marsh-6683'

# %%
espn_url.split('-')[-1]
# Out:
# '6683'

# %%
player_id = ""
for character in espn_url.split('-')[-1]:
    if character in '1234567890':
        player_id = player_id + character
    else:
        break
print(player_id)
# Out:
# 6683

# %%
def get_player_id(s):
    player_id = ""
    for character in s.split('-')[-1]:
        if character in '1234567890':
            player_id = player_id + character
        else:
            break
    return player_id

# %%
player_id = get_player_id(espn_url)
player_id
# Out:
# '6683'

# %%
url = 'https://hs-consumer-api.espncricinfo.com/v1/pages/player/home?playerId='+player_id

# %%
url
# Out:
# 'https://hs-consumer-api.espncricinfo.com/v1/pages/player/home?playerId=6683'

# %%
response = requests.get('https://hs-consumer-api.espncricinfo.com/v1/pages/player/home?playerId='+'35320')

# %%
response.status_code
# Out:
# 200

# %%
response = requests.get(url)

# %%
player_dict = json.loads(response.content.decode())

# %%
player_dict['player']['dateOfBirth']
# Out:
# {'year': 1983, 'month': 7, 'date': 9}

# %%
player_dict['player']['battingStyles'][0]
# Out:
# 'lhb'

# %%
player_dict['player']['country']['name']
# Out:
# 'Australia'

# %%
# soup = BeautifulSoup(response.content,'lxml')

# %%
# soup.find('span',class_='ds-text-comfortable-s')

# %%
# for data in soup.find_all('div',class_='ds-pl-3'):
#     print(data.text)

# %%
# def get_data(soup_obj):
#     count = 0
#     lst = {}
#     temp_lst = []
#     for data in soup_obj.find('div',class_='ds-grid lg:ds-grid-cols-3 ds-grid-cols-2 ds-gap-4 ds-mb-8').find_all('p'):
#         count = count + 1
#         temp_lst.append(data.text)
#         if count == 2:
#             lst[temp_lst[0]] = temp_lst[1]
#             count = 0
#             temp_lst = []
#     return lst

# %%
#get_data(soup)

# %%
df_08 = dfs[2008]

# %%
row = df_08[df_08['StrikerName']=='Shaun Marsh'].index.values[0]

# %%
df_08.at[row,'TCompetitionID'] = 1

# %%
df_08
# Out:
#                StrikerName  PlayerId  Matches  PlayerDOB  RightHandedBat  \
# 0              Shaun Marsh        41       11        NaN             NaN
# 1           Gautam Gambhir         0       14        NaN             NaN
# 2        Sanath Jayasuriya         0       14        NaN             NaN
# 3             Shane Watson       104       15        NaN             NaN
# 4             Graeme Smith         0       11        NaN             NaN
# ..                     ...       ...      ...        ...             ...
# 145  Paidikalva Vijaykumar         0        9        NaN             NaN
# 146           Abdur Razzak         0        1        NaN             NaN
# 147         Abhinav Mukund         0        2        NaN             NaN
# 148    Lakshmipathy Balaji         0        9        NaN             NaN
# 149            Munaf Patel       460       15        NaN             NaN
#
#      Nationality  TCompetitionID  TStrikerID  TTeamID TeamCode  ... Outs  \
# ...

# %%
# for df in dfs.values():
#     for name in df['StrikerName']:
#         espn_url = googler(name)
#         response = requests.get(espn_url)
#         soup = BeautifulSoup(response.content,'lxml')
#         nation = soup.find('span',class_='ds-text-comfortable-s').text
#         print(f'{name} : {nation}')

# %%
df_08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StrikerName        150 non-null    object
#  1   PlayerId           150 non-null    int64
#  2   Matches            150 non-null    int64
#  3   PlayerDOB          0 non-null      float64
#  4   RightHandedBat     0 non-null      float64
#  5   Nationality        0 non-null      float64
#  6   TCompetitionID     150 non-null    int64
#  7   TStrikerID         0 non-null      float64
#  8   TTeamID            0 non-null      float64
#  9   TeamCode           150 non-null    object
#  10  TeamName           150 non-null    object
#  11  CompetitionID      150 non-null    int64
#  12  TeamID             0 non-null      float64
#  13  StrikerID          0 non-null      float64
#  14  Innings            150 non-null    int64
#  15  Extras             0 non-null      float64
# ...

# %%
dfs[2008]['StrikeRate']
# Out:
# 0      139.68
# 1      140.89
# 2      167.63
# 3      151.76
# 4      121.82
#         ...
# 145    100.00
# 146      0.00
# 147      0.00
# 148      0.00
# 149      0.00
# Name: StrikeRate, Length: 150, dtype: float64

# %%
dfs[2023].columns
# Out:
# Index(['StrikerName', 'PlayerId', 'Matches', 'PlayerDOB', 'RightHandedBat',
#        'Nationality', 'TCompetitionID', 'TStrikerID', 'TTeamID', 'TeamCode',
#        'TeamName', 'CompetitionID', 'TeamID', 'StrikerID', 'Innings', 'Extras',
#        'TotalRuns', 'Balls', 'Dotballs', 'StrikeRate', 'DBPercent', 'DBFreq',
#        'BdryFreq', 'BdryPercent', 'RPSS', 'ScoringBalls', 'Ones', 'Twos',
#        'Threes', 'Fours', 'Sixes', 'Outs', 'NotOuts', 'BattingAveragesss',
#        'FiftyPlusRuns', 'Centuries', 'DoubleCenturies', 'HighestScore',
#        'BattingAverage', 'Catches', 'Stumpings'],
#       dtype='object')

# %%
required_columns = ['StrikerName','PlayerId','Matches','PlayerDOB','RightHandedBat','Nationality','TeamCode','TeamName','Innings','TotalRuns','Balls','StrikeRate','Fours','Sixes','Outs','NotOuts','FiftyPlusRuns','Centuries','HighestScore','BattingAverage']
for year,df in dfs.items():
    dfs[year] = df[required_columns]

# %%
dfs[2008]['PlayerDOB'].astype(str)
# Out:
# 0      nan
# 1      nan
# 2      nan
# 3      nan
# 4      nan
#       ...
# 145    nan
# 146    nan
# 147    nan
# 148    nan
# 149    nan
# Name: PlayerDOB, Length: 150, dtype: object

# %%
for df in dfs.values():
    df['PlayerDOB'] = df['PlayerDOB'].astype(str)
    df['Nation'] = None
    df['BattingStyle'] = None
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8860\2365936316.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PlayerDOB'] = df['PlayerDOB'].astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8860\2365936316.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Nation'] = None
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8860\2365936316.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
for df in dfs.values():
    df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   StrikerName     150 non-null    object
#  1   PlayerId        150 non-null    int64
#  2   Matches         150 non-null    int64
#  3   PlayerDOB       150 non-null    object
#  4   RightHandedBat  0 non-null      float64
#  5   Nationality     0 non-null      float64
#  6   TeamCode        150 non-null    object
#  7   TeamName        150 non-null    object
#  8   Innings         150 non-null    int64
#  9   TotalRuns       150 non-null    int64
#  10  Balls           150 non-null    int64
#  11  StrikeRate      150 non-null    float64
#  12  Fours           150 non-null    int64
#  13  Sixes           150 non-null    int64
#  14  Outs            150 non-null    int64
#  15  NotOuts         150 non-null    int64
#  16  FiftyPlusRuns   150 non-null    int64
# ...

# %%
for df in dfs.values():
    for name in df['StrikerName']:
        try:
            espn_url = googler(name)
            
            player_id = get_player_id(espn_url)
            
            url = 'https://hs-consumer-api.espncricinfo.com/v1/pages/player/home?playerId=' + player_id
            
            response = requests.get(url)
            
            player_dict = json.loads(response.content.decode())
            
            dob = player_dict['player']['dateOfBirth']
            
            row = df[df['StrikerName']==name].index.values[0]
            
            df.at[row,'PlayerDOB'] = f"{dob['date']}-{dob['month']}-{dob['year']}"
            
            df.at[row,'BattingStyle'] = player_dict['player']['battingStyles'][0]
            
            df.at[row,'Nation'] = player_dict['player']['country']['name']
            
        except Exception as e:
            print(f'{name} : {e}')
# Out:
# Tillakaratne Dilshan : HTTP Error 429: Too Many Requests
# Manoj Tiwary : HTTP Error 429: Too Many Requests
# Niraj Patel : HTTP Error 429: Too Many Requests
# Debabrata Das : HTTP Error 429: Too Many Requests
# Simon Katich : HTTP Error 429: Too Many Requests
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 4
#       2 for name in df['StrikerName']:
#       3     try:
# ----> 4         espn_url = googler(name)
#       6         player_id = get_player_id(espn_url)
#       8         url = 'https://hs-consumer-api.espncricinfo.com/v1/pages/player/home?playerId=' + player_id
#
# Cell In[29], line 2, in googler(query)
#       1 def googler(query):
# ----> 2     for url in search(query,num=10):
#       3         if 'https://www.espncricinfo.com/cricketers' in url:
#       4             return url
#
# ...
