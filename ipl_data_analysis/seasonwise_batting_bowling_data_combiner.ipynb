# %%
import pandas as pd
import numpy as np

# %%
combined = {}

# %%
for year in range(2008,2024):
    combined[year] = pd.read_csv(f'seasonwise/combined/combined_{year}.csv')

# %%
2008 - combined[2008]['PlayerDOB'].apply(lambda x: x.split('-')[-1]).astype(int)
# Out:
# 0      25
# 1      27
# 2      39
# 3      27
# 4      27
#        ..
# 153    20
# 154    29
# 155    26
# 156    31
# 157    23
# Name: PlayerDOB, Length: 158, dtype: int32

# %%
# for column in combined[2008].columns:
#     if combined[2008][column].dtype == 'object' or combined[2008][column].dtype == 'bool':
#         continue
#     else:
#         combined[2008][column].fillna(0,inplace=True)

# %%
# for column in combined[2008].columns:
#     if combined[2008][column].dtype == 'bool':
#         continue
#     elif combined[2008][column].dtype == 'object':
#         combined[2008][column].fillna('NA',inplace=True)
#     else:
#         combined[2008][column].fillna(0,inplace=True)

# %%
combined[2008].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               158 non-null    object
#  1   PlayerDOB          158 non-null    object
#  2   TotalRuns          150 non-null    float64
#  3   Balls              150 non-null    float64
#  4   StrikeRate         150 non-null    float64
#  5   Fours              150 non-null    float64
#  6   Sixes              150 non-null    float64
#  7   Outs               150 non-null    float64
#  8   NotOuts            150 non-null    float64
#  9   FiftyPlusRuns      150 non-null    float64
#  10  Centuries          150 non-null    float64
#  11  HighestScore       150 non-null    object
#  12  BattingAverage     150 non-null    float64
#  13  Nation             158 non-null    object
#  14  BattingStyle       158 non-null    object
#  15  TotalRunsConceded  87 non-null     float64
#  16  DotBallsBowled     87 non-null     float64
#  17  BowlingAverage     87 non-null     float64
#  18  BowlingStrikeRate  87 non-null     float64
#  19  EconomyRate        87 non-null     float64
#  20  OversBowled        87 non-null     float64
#  21  FoursConceded      87 non-null     float64
#  22  SixesConceded      87 non-null     float64
#  23  Wickets            87 non-null     float64
#  24  BBIW               87 non-null     object
#  25  BBMW               87 non-null     object
#  26  Maidens            87 non-null     float64
#  27  FourWickets        87 non-null     float64
#  28  FiveWickets        87 non-null     float64
#  29  BallsBowled        87 non-null     float64
#  30  TeamCode           158 non-null    object
#  31  TeamName           158 non-null    object
#  32  Innings            158 non-null    float64
#  33  Matches            158 non-null    float64
#  34  Nationality        158 non-null    object
#  35  RightHandedBat     158 non-null    bool
# dtypes: bool(1), float64(25), object(10)
# memory usage: 43.5+ KB

# %%
def highest_score_parser(score):
    if not score is np.nan:
        if score.endswith('*'):
            return score[:-1],'Not Dismissed'
        else:
            return score,'Dismissed'
    else:
        return 'DNB','NA'

# %%
# combined[2008]['IsDismissed'] = combined[2008].HighestScore.apply(lambda x:highest_score_parser(x)[1])

# %%
# combined[2008]['HighestScore'] = combined[2008].HighestScore.apply(lambda x:highest_score_parser(x)[0])

# %%
# combined[2008].drop(columns=['BBMW'],inplace=True)

# %%
def bowling_parser(figures):
    if figures is np.nan:
        return 0,0
    else:
        wickets,runs = tuple(map(int,figures.split('/')))
        return wickets,runs

# %%
combined[2008].BBIW
# Out:
# 0       NaN
# 1       NaN
# 2      3/14
# 3      4/29
# 4       NaN
#        ...
# 153    1/33
# 154    3/15
# 155    1/50
# 156    1/31
# 157    2/19
# Name: BBIW, Length: 158, dtype: object

# %%
# combined[2008]['BestBowlingWickets'] = combined[2008].BBIW.apply(lambda x:bowling_parser(x)[0])
# combined[2008]['BestBowlingRuns'] = combined[2008].BBIW.apply(lambda x:bowling_parser(x)[1])
# combined[2008].drop(columns=['BBIW'],inplace=True)

# %%
# combined[2008][['Name','BestBowlingWickets','BestBowlingRuns']].sort_values(by=['BestBowlingWickets','BestBowlingRuns'],ascending=[False,True]).head(30)

# %%
for year,df in combined.items():
    df['Year'] = year
    df['Age'] = year - df['PlayerDOB'].apply(lambda x: x.split('-')[-1]).astype(int)

# %%
for df in combined.values():
    for column in df.columns:
        if df[column].dtype == 'object' or df[column].dtype == 'bool':
            continue
        else:
            df[column].fillna(0,inplace=True)

# %%
for df in combined.values():
    df['IsDismissed'] = df.HighestScore.apply(lambda x:highest_score_parser(x)[1])
    df['HighestScore'] = df.HighestScore.apply(lambda x:highest_score_parser(x)[0])
    df.drop(columns=['BBMW'],inplace=True)

# %%
for df in combined.values():
    df['BestBowlingWickets'] = df.BBIW.apply(lambda x:bowling_parser(x)[0])
    df['BestBowlingRuns'] = df.BBIW.apply(lambda x:bowling_parser(x)[1])
    df.drop(columns=['BBIW'],inplace=True)

# %%
for year,df in combined.items():
    print(f'{year} : {df.shape}')
# Out:
# 2008 : (158, 39)
# 2009 : (137, 39)
# 2010 : (168, 39)
# 2011 : (184, 39)
# 2012 : (175, 39)
# 2013 : (187, 39)
# 2014 : (147, 39)
# 2015 : (139, 39)
# 2016 : (152, 39)
# 2017 : (153, 39)
# 2018 : (145, 39)
# 2019 : (161, 39)
# 2020 : (144, 39)
# 2021 : (162, 39)
# 2022 : (186, 39)
# 2023 : (198, 39)

# %%
combined[2008].append(combined[2009]).shape
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8316\1223167.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined[2008].append(combined[2009]).shape
# (295, 39)

# %%
pd.concat([combined[2008],combined[2009]],ignore_index=True)
# Out:
#                      Name   PlayerDOB  TotalRuns  Balls  StrikeRate  Fours  \
# 0             Shaun Marsh    9-7-1983      616.0  441.0      139.68   59.0
# 1          Gautam Gambhir  14-10-1981      534.0  379.0      140.89   68.0
# 2       Sanath Jayasuriya   30-6-1969      518.0  309.0      167.63   58.0
# 3            Shane Watson   17-6-1981      472.0  311.0      151.76   47.0
# 4            Graeme Smith    1-2-1981      441.0  362.0      121.82   54.0
# ..                    ...         ...        ...    ...         ...    ...
# 290      Charl Langeveldt  17-12-1974        0.0    0.0        0.00    0.0
# 291  Harmeet Singh Bansal   9-10-1987        0.0    0.0        0.00    0.0
# 292         Anureet Singh    2-3-1988        0.0    0.0        0.00    0.0
# 293      Vikramjeet Malik    9-5-1983        0.0    0.0        0.00    0.0
# 294          Vikram Singh   17-9-1984        0.0    0.0        0.00    0.0
#
#      Sixes  Outs  NotOuts  FiftyPlusRuns  ...               TeamName Innings  \
# 0     26.0   9.0      2.0            5.0  ...           Punjab Kings    11.0
# 1      8.0  13.0      1.0            5.0  ...         Delhi Capitals    14.0
# 2     31.0  12.0      2.0            2.0  ...         Mumbai Indians    14.0
# 3     19.0  10.0      5.0            4.0  ...       Rajasthan Royals    15.0
# 4      8.0   9.0      2.0            3.0  ...       Rajasthan Royals    11.0
# ..     ...   ...      ...            ...  ...                    ...     ...
# 290    0.0   0.0      0.0            0.0  ...  Kolkata Knight Riders     1.0
# 291    0.0   0.0      0.0            0.0  ...        Deccan Chargers     7.0
# 292    0.0   0.0      0.0            0.0  ...  Kolkata Knight Riders     2.0
# 293    0.0   0.0      0.0            0.0  ...           Punjab Kings     5.0
# 294    0.0   0.0      0.0            0.0  ...           Punjab Kings     4.0
#
#      Matches Nationality RightHandedBat  Year  Age    IsDismissed  \
# 0       11.0    Overseas          False  2008   25      Dismissed
# 1       14.0      Indian          False  2008   27      Dismissed
# 2       14.0    Overseas          False  2008   39  Not Dismissed
# 3       15.0    Overseas           True  2008   27  Not Dismissed
# 4       11.0    Overseas          False  2008   27      Dismissed
# ..       ...         ...            ...   ...  ...            ...
# 290      1.0    Overseas           True  2009   35             NA
# 291      7.0      Indian           True  2009   22             NA
# 292      3.0      Indian           True  2009   21             NA
# 293      5.0      Indian           True  2009   26             NA
# 294      5.0      Indian           True  2009   25             NA
#
#      BestBowlingWickets  BestBowlingRuns
# 0                     0                0
# 1                     0                0
# 2                     3               14
# 3                     4               29
# 4                     0                0
# ..                  ...              ...
# 290                   3               15
# 291                   3               24
# 292                   3               23
# 293                   2               14
# 294                   3               29
#
# [295 rows x 39 columns]

# %%
final_df = None

# %%
for df in combined.values():
    if final_df is None:
        final_df = df
    else:
        final_df = pd.concat([final_df,df],ignore_index=True)

# %%
final_df.shape
# Out:
# (2596, 39)

# %%
final_df[['Name','Year']].sort_values(by=['Name','Year'],ascending=[True,True]).head(50)
# Out:
#                        Name  Year
# 62           AB de Villiers  2008
# 347          AB de Villiers  2010
# 488          AB de Villiers  2011
# 671          AB de Villiers  2012
# 839          AB de Villiers  2013
# 1019         AB de Villiers  2014
# 1159         AB de Villiers  2015
# 1297         AB de Villiers  2016
# 1488         AB de Villiers  2017
# 1611         AB de Villiers  2018
# 1755         AB de Villiers  2019
# 1915         AB de Villiers  2020
# 2068         AB de Villiers  2021
# 75            Aakash Chopra  2008
# 254           Aakash Chopra  2009
# 395             Aaron Finch  2010
# 544             Aaron Finch  2011
# 729             Aaron Finch  2012
# 832             Aaron Finch  2013
# 1034            Aaron Finch  2014
# 1238            Aaron Finch  2015
# 1307            Aaron Finch  2016
# 1470            Aaron Finch  2017
# 1643            Aaron Finch  2018
# 1936            Aaron Finch  2020
# 2287            Aaron Finch  2022
# 638         Aavishkar Salvi  2011
# 2555           Abdul Basith  2023
# 1958            Abdul Samad  2020
# 2103            Abdul Samad  2021
# 2359            Abdul Samad  2022
# 2452            Abdul Samad  2023
# 146            Abdur Razzak  2008
# 2360         Abhijeet Tomar  2022
# 423        Abhimanyu Mithun  2010
# 561        Abhimanyu Mithun  2011
# 975        Abhimanyu Mithun  2013
# 2281        Abhinav Manohar  2022
# 2465        Abhinav Manohar  2023
# 147          Abhinav Mukund  2008
# 931          Abhinav Mukund  2013
# 336   Abhishek Jhunjhunwala  2010
# 592   Abhishek Jhunjhunwala  2011
# 749   Abhishek Jhunjhunwala  2012
# 24           Abhishek Nayar  2008
# 184          Abhishek Nayar  2009
# 362          Abhishek Nayar  2010
# 535          Abhishek Nayar  2011
# 734          Abhishek Nayar  2012
# 900          Abhishek Nayar  2013

# %%
final_df[final_df['Name'] == 'Virat Kohli'][['Age','TotalRuns']]
# Out:
#       Age  TotalRuns
# 37     20      165.0
# 175    21      246.0
# 313    22      307.0
# 464    23      557.0
# 662    24      364.0
# 824    25      634.0
# 1027   26      359.0
# 1160   27      505.0
# 1295   28      973.0
# 1469   29      308.0
# 1606   30      530.0
# 1752   31      464.0
# 1914   32      466.0
# 2061   33      405.0
# 2233   34      341.0
# 2401   35      639.0

# %%
final_df[final_df['Name'] == 'Anil Kumble']['Year']
# Out:
# 111    2008
# 247    2009
# 422    2010
# Name: Year, dtype: int64

# %%
# final_df.to_csv('seasonwise/for_all_seasons.csv',index=False)
